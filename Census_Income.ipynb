# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data = pd.read_csv(r"C:\Users\lenovo\Desktop\Python\Census-Income\census-income_.csv",na_values='?',skipinitialspace=True)
data = pd.read_csv(r"census-income_.csv",na_values='?',skipinitialspace=True)
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country Unnamed: 14
# 0          2174             0              40  United-States       <=50K
# 1             0             0              13  United-States       <=50K
# 2             0             0              40  United-States       <=50K
# 3             0             0              40  United-States       <=50K
# 4             0             0              40           Cuba       <=50K

# %% [markdown]
# ### Data Preprocessing

# %%
data.columns = data.columns.str.replace(' ','_')

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Unnamed:_14'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace('-','.')
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'Unnamed:_14'],
#       dtype='object')

# %%
data['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', nan, 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
data['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
data.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# Unnamed:_14          0
# dtype: int64

# %%
data.describe().T  # T - Transpose the columns to rows, rows to cloumns.
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education.num   32561.0      10.080679       2.572720      1.0       9.0
# capital.gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital.loss    32561.0      87.303830     402.960219      0.0       0.0
# hours.per.week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education.num       10.0      12.0       16.0
# capital.gain         0.0       0.0    99999.0
# capital.loss         0.0       0.0     4356.0
# hours.per.week      40.0      45.0       99.0

# %% [markdown]
# ### Data Manipulation

# %%
# a).Extracting the "education" column and store it in "census_ed"
census_ed=data[['education']]
census_ed.head()
# Out:
#    education
# 0  Bachelors
# 1  Bachelors
# 2    HS-grad
# 3       11th
# 4  Bachelors

# %%
# b).Extracting all the columns from “age” to “relationship” and store it in “census_seq”.
census_seq=data.iloc[:,0:8]     # iloc function extarct the rows and columns
census_seq.head()
# Out:
#    age         workclass  fnlwgt  education  education.num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital.status         occupation   relationship
# 0       Never-married       Adm-clerical  Not-in-family
# 1  Married-civ-spouse    Exec-managerial        Husband
# 2            Divorced  Handlers-cleaners  Not-in-family
# 3  Married-civ-spouse  Handlers-cleaners        Husband
# 4  Married-civ-spouse     Prof-specialty           Wife

# %%
# c).Extract the column number “0”, “5”, “6” and store it in “census_col”.
census_col=data.iloc[:,[0,5,6]]
census_col.head()
# Out:
#    age      marital.status         occupation
# 0   39       Never-married       Adm-clerical
# 1   50  Married-civ-spouse    Exec-managerial
# 2   38            Divorced  Handlers-cleaners
# 3   53  Married-civ-spouse  Handlers-cleaners
# 4   28  Married-civ-spouse     Prof-specialty

# %%
#d).Extracting all the male employees who work in state-gov and store it in “male_gov”.
male_gov=data[(data['workclass']=='State-gov')&(data['sex']=='Male')]
male_gov.head()
# Out:
#      age  workclass  fnlwgt     education  education.num      marital.status  \
# 0     39  State-gov   77516     Bachelors             13       Never-married
# 11    30  State-gov  141297     Bachelors             13  Married-civ-spouse
# 34    22  State-gov  311512  Some-college             10  Married-civ-spouse
# 48    41  State-gov  101603     Assoc-voc             11  Married-civ-spouse
# 123   29  State-gov  267989     Bachelors             13  Married-civ-spouse
#
#          occupation   relationship                race   sex  capital.gain  \
# 0      Adm-clerical  Not-in-family               White  Male          2174
# 11   Prof-specialty        Husband  Asian-Pac-Islander  Male             0
# 34    Other-service        Husband               Black  Male             0
# 48     Craft-repair        Husband               White  Male             0
# 123  Prof-specialty        Husband               White  Male             0
#
#      capital.loss  hours.per.week native.country Unnamed:_14
# 0               0              40  United-States       <=50K
# 11              0              40          India        >50K
# 34              0              15  United-States       <=50K
# 48              0              40  United-States       <=50K
# 123             0              50  United-States        >50K

# %%
#Exctracting all Female employees who work in Private
female_priv=data[(data['workclass']=='Private')&(data['sex']=='Female')]
female_priv.head()
# Out:
#     age workclass  fnlwgt  education  education.num         marital.status  \
# 4    28   Private  338409  Bachelors             13     Married-civ-spouse
# 5    37   Private  284582    Masters             14     Married-civ-spouse
# 6    49   Private  160187        9th              5  Married-spouse-absent
# 8    31   Private   45781    Masters             14          Never-married
# 12   23   Private  122272  Bachelors             13          Never-married
#
#          occupation   relationship   race     sex  capital.gain  capital.loss  \
# 4    Prof-specialty           Wife  Black  Female             0             0
# 5   Exec-managerial           Wife  White  Female             0             0
# 6     Other-service  Not-in-family  Black  Female             0             0
# 8    Prof-specialty  Not-in-family  White  Female         14084             0
# 12     Adm-clerical      Own-child  White  Female             0             0
#
#     hours.per.week native.country Unnamed:_14
# 4               40           Cuba       <=50K
# 5               40  United-States       <=50K
# 6               16        Jamaica       <=50K
# 8               50  United-States        >50K
# 12              30  United-States       <=50K

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education.num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital.status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country Unnamed:_14
# 0          2174             0              40  United-States       <=50K
# 1             0             0              13  United-States       <=50K
# 2             0             0              40  United-States       <=50K
# 3             0             0              40  United-States       <=50K
# 4             0             0              40           Cuba       <=50K

# %%
# e).Extract all the 39 year olds who either have a bachelor's degree or who are native of the United States and 
#store the result in “census_us”.
         
         #We are writing a condition where age should be 39 and storing it in census. This condition is then taken and 
         #applied on the next one to get the result.

census=data[(data['age']==39)]
#census.head()
census_us=census[(census['education']=='Bachelors')|(census['native.country']=='United-States')]
census_us.head()
# Out:
#      age         workclass  fnlwgt     education  education.num  \
# 0     39         State-gov   77516     Bachelors             13
# 28    39           Private  367260       HS-grad              9
# 129   39           Private  365739  Some-college             10
# 166   39       Federal-gov  235485    Assoc-acdm             12
# 320   39  Self-emp-not-inc  174308       HS-grad              9
#
#          marital.status       occupation   relationship   race   sex  \
# 0         Never-married     Adm-clerical  Not-in-family  White  Male
# 28             Divorced  Exec-managerial  Not-in-family  White  Male
# 129            Divorced     Craft-repair  Not-in-family  White  Male
# 166       Never-married  Exec-managerial  Not-in-family  White  Male
# 320  Married-civ-spouse  Exec-managerial        Husband  White  Male
#
#      capital.gain  capital.loss  hours.per.week native.country Unnamed:_14
# 0            2174             0              40  United-States       <=50K
# 28              0             0              80  United-States       <=50K
# 129             0             0              40  United-States       <=50K
# 166             0             0              42  United-States       <=50K
# 320             0             0              40  United-States       <=50K

# %%
# f).Extract 200 random rows from the "census" data frame and store it in "census_200"
census_200=data.sample(200)
census_200.head()
# Out:
#        age  workclass  fnlwgt   education  education.num      marital.status  \
# 30378   22  Local-gov  121144   Bachelors             13       Never-married
# 7213    33    Private   80145     HS-grad              9  Married-civ-spouse
# 4042    39    Private   99065   Bachelors             13  Married-civ-spouse
# 27232   44    Private  247880   Assoc-voc             11            Divorced
# 30681   39    Private  110426  Assoc-acdm             12  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital.gain  \
# 30378     Prof-specialty      Own-child  Black  Female             0
# 7213    Transport-moving        Husband  White    Male             0
# 4042   Handlers-cleaners           Wife  White  Female             0
# 27232    Exec-managerial  Not-in-family  White    Male          8614
# 30681    Exec-managerial           Wife  White  Female         15024
#
#        capital.loss  hours.per.week native.country Unnamed:_14
# 30378             0              18  United-States       <=50K
# 7213              0              60  United-States       <=50K
# 4042              0              40         Poland        >50K
# 27232             0              40  United-States        >50K
# 30681             0              45  United-States        >50K

# %%
# g).Getting the count of different levels of the “workclass” column.
 
    #value_counts() helps us to get the total count of all elements present in a particular column.
    
data[['workclass']].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# dtype: int64

# %%
# h).Calculating the mean of "capital.gain" column grouped according to "workclass".
data.groupby(['workclass'])['capital.gain'].mean()
# Out:
# workclass
# Federal-gov          833.232292
# Local-gov            880.202580
# Never-worked           0.000000
# Private              889.217792
# Self-emp-inc        4875.693548
# Self-emp-not-inc    1886.061787
# State-gov            701.699538
# Without-pay          487.857143
# Name: capital.gain, dtype: float64

# %%
#Create a separate dataframe with the details of males and females from the census data that has income more than 50,000.
data['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
income=data['Unnamed:_14']
data['income']=income
data.head()
# Out:
#    age         workclass  fnlwgt  education  education.num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital.status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country Unnamed:_14  \
# 0          2174             0              40  United-States       <=50K
# 1             0             0              13  United-States       <=50K
# 2             0             0              40  United-States       <=50K
# 3             0             0              40  United-States       <=50K
# 4             0             0              40           Cuba       <=50K
#
#   income
# 0  <=50K
# 1  <=50K
# 2  <=50K
# 3  <=50K
# 4  <=50K

# %%
data['Unnamed:_14'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: Unnamed:_14, dtype: int64

# %%
data['income'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
data=pd.DataFrame(data)
data.drop("Unnamed:_14",axis=1,inplace=True)
data.head()
# Out:
#    age         workclass  fnlwgt  education  education.num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital.status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
data.tail()
# Out:
#        age     workclass  fnlwgt   education  education.num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital.status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital.gain  capital.loss  hours.per.week native.country income
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K

# %%
male_50k=data[(data['sex']=='Male') & (data['income']=='>50K')]
female_50K=data[(data['sex']=='Female') & (data['income']=='>50K')]

# %%
female_50K.head()
# Out:
#     age         workclass  fnlwgt    education  education.num  \
# 8    31           Private   45781      Masters             14
# 19   43  Self-emp-not-inc  292175      Masters             14
# 52   47           Private   51835  Prof-school             15
# 67   53           Private  169846      HS-grad              9
# 84   44           Private  343591      HS-grad              9
#
#         marital.status       occupation   relationship   race     sex  \
# 8        Never-married   Prof-specialty  Not-in-family  White  Female
# 19            Divorced  Exec-managerial      Unmarried  White  Female
# 52  Married-civ-spouse   Prof-specialty           Wife  White  Female
# 67  Married-civ-spouse     Adm-clerical           Wife  White  Female
# 84            Divorced     Craft-repair  Not-in-family  White  Female
#
#     capital.gain  capital.loss  hours.per.week native.country income
# 8          14084             0              50  United-States   >50K
# 19             0             0              45  United-States   >50K
# 52             0          1902              60       Honduras   >50K
# 67             0             0              40  United-States   >50K
# 84         14344             0              40  United-States   >50K

# %%
male_50k.head()
# Out:
#     age         workclass  fnlwgt     education  education.num  \
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
# 14   40           Private  121772     Assoc-voc             11
#
#         marital.status       occupation relationship                race  \
# 7   Married-civ-spouse  Exec-managerial      Husband               White
# 9   Married-civ-spouse  Exec-managerial      Husband               White
# 10  Married-civ-spouse  Exec-managerial      Husband               Black
# 11  Married-civ-spouse   Prof-specialty      Husband  Asian-Pac-Islander
# 14  Married-civ-spouse     Craft-repair      Husband  Asian-Pac-Islander
#
#      sex  capital.gain  capital.loss  hours.per.week native.country income
# 7   Male             0             0              45  United-States   >50K
# 9   Male          5178             0              40  United-States   >50K
# 10  Male             0             0              80  United-States   >50K
# 11  Male             0             0              40          India   >50K
# 14  Male             0             0              40            NaN   >50K

# %%
#Checking % of people from US who earn <=50,000 anually and work under private.
p_le50=data[(data['native.country']=='United-States')&(data['workclass']=='Private')&(data['income']=='<=50K')]
total=len(data)
percentage=(len(p_le50)/total)*100
percentage
# Out:
# 47.891649519363654

# %%
# Calculating the percentage of married people in the census data.
data['marital.status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital.status, dtype: int64

# %%
#calculating % of married people
total=len(data['marital.status'])
married=14976+418+23
precen_mar=(married/total)*100
precen_mar
# Out:
# 47.34805442093302

# %%
#Calculatig the percentage of high school graduates earning more than 50,000 annually.
data['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
hs_m50k=len(data[(data['education']=='HS-grad')&(data['income']=='>50K')])
percentage_hs_m50k=(hs_m50k/total)*100
percentage_hs_m50k
# Out:
# 5.144190903227788

# %% [markdown]
# ## Linear Regression Model:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
lr=LinearRegression()

# %%
#independent variable is "education.num".
x=data[['education.num']]
#dependent variable is "hours.per.week"
y=data[['hours.per.week']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
error=y_test-y_pred

# %%
error
# Out:
#        hours.per.week
# 9646        30.044869
# 709        -13.159243
# 7385         7.432533
# 16671        0.371349
# 21932        1.840757
# ...               ...
# 29663       -1.832763
# 29310        0.371349
# 29661       -0.363355
# 19491       -1.098059
# 2861         5.514277
#
# [9769 rows x 1 columns]

# %%
print('mean_squared_error :',mean_squared_error(y_test,y_pred))
print('root-mean-square error :',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mean_squared_error : 147.15261838664162
# root-mean-square error : 12.130647896408568

# %% [markdown]
# ### Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
lo=LogisticRegression()

# %%
data.shape
# Out:
# (32561, 15)

# %%
data[['occupation']].value_counts()
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# dtype: int64

# %%
#occupation is independent
x=data['occupation']
x=pd.DataFrame(x)

# %%
x[['occupation']].value_counts()
# Out:
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# dtype: int64

# %%
data['income'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
y=data['income'].replace('<=50K',0).replace('>50K',1)
y.value_counts()
# Out:
# 0    24720
# 1     7841
# Name: income, dtype: int64

# %%
len(y)
# Out:
# 32561

# %%
#giving particular labels to the elements in my columns
L=LabelEncoder()

# %%
x=L.fit_transform(x)
# Out:
# C:\Users\Sairam\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
x=pd.DataFrame(x)

# %%
x.head()
# Out:
#    0
# 0  0
# 1  3
# 2  5
# 3  5
# 4  9

# %%
x.value_counts()
# Out:
# 9     4140
# 2     4099
# 3     4066
# 0     3770
# 11    3650
# 7     3295
# 6     2002
# 14    1843
# 13    1597
# 5     1370
# 4      994
# 12     928
# 10     649
# 8      149
# 1        9
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.35,random_state=1)
lo=LogisticRegression()
lo.fit(x_train,y_train)
y_pred=lo.predict(x_test)

# %%
print('confusion_matrix :',confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix : [[8800 2597]
#  [   0    0]]
# accuracy_score : 0.7721330174607353

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
data.head()
# Out:
#    age         workclass  fnlwgt  education  education.num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital.status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
data.education=data.education.replace(['Preschool','1st-4th','5th-6th','7th-8th','9th','10th','11th','12th'],'school')
data.education = data.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'Higher')
data['marital.status']= data['marital.status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')
data['marital.status']= data['marital.status'].replace(['Never-married'], 'not-married')
data['marital.status']= data['marital.status'].replace(['Divorced', 'Separated','Widowed','Married-spouse-absent'], 'other')
data.income = data.income.replace('<=50K', 0)
data.income = data.income.replace('>50K', 1)
data.head()
# Out:
#    age         workclass  fnlwgt  education  education.num marital.status  \
# 0   39         State-gov   77516  Bachelors             13    not-married
# 1   50  Self-emp-not-inc   83311  Bachelors             13        married
# 2   38           Private  215646    HS-grad              9          other
# 3   53           Private  234721     school              7        married
# 4   28           Private  338409  Bachelors             13        married
#
#           occupation   relationship   race     sex  capital.gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital.loss  hours.per.week native.country  income
# 0             0              40  United-States       0
# 1             0              13  United-States       0
# 2             0              40  United-States       0
# 3             0              40  United-States       0
# 4             0              40           Cuba       0

# %%
data=data.apply(L.fit_transform)
data.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   22          6    2671          0             12               1
# 1   33          5    2926          0             12               0
# 2   21          3   14086          2              8               2
# 3   36          3   15336          5              6               0
# 4   11          3   19355          0             12               0
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           0             1     4    1            25             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
#
#    hours.per.week  native.country  income
# 0              39              38       0
# 1              12              38       0
# 2              39              38       0
# 3              39              38       0
# 4              39               4       0

# %%
#independent
x=data.iloc[:,:-1]
#dependent
y=data.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

# %%
print('confusion_matrix :',confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix : [[6568  836]
#  [ 982 1383]]
# accuracy_score : 0.8139011157743884

# %% [markdown]
# ### Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=1)
rf=RandomForestClassifier(n_estimators=300)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

# %%
print('confusion_matrix :',confusion_matrix(y_pred,y_test))
print('accuracy_score :',accuracy_score(y_test,y_pred))
# Out:
# confusion_matrix : [[4640  515]
#  [ 386  972]]
# accuracy_score : 0.8616612927990174
